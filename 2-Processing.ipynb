# %% [markdown]
# # Data Pre-Processing & NLP

# %%
import numpy as np
import pandas as pd

from langdetect import detect
import pandas as pd
import re
import unicodedata

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ## Merging of all post requests

# %%
# Load dataset 1
df0 = pd.read_csv('ig_posts.csv')
df1 = pd.read_csv('newsupdate_posts.csv')
df3 = pd.read_csv('newsupdate_posts2.csv')
dftop1= pd.read_csv('newsupdate_posts_top.csv')

# Load dataset 2
df2 = pd.read_csv('fake_posts_complete.csv')

# Add a new column 'dataset' with labels in both DataFrames
df0['is_fake'] = '0'
df1['is_fake'] = '0'
df3['is_fake'] = '0'
dftop1['is_fake'] = '0'
df2['is_fake'] = '1'


# Merge the datasets
merged_df = pd.concat([df0,df1, df3,dftop1,df2], axis=0)
merged_df=merged_df.reset_index()

# %% [markdown]
# ## Problem 1: Many duplicates included in the dataset, leaves us with less than half of entries

# %%
merged_df.drop_duplicates(subset='caption', keep="first", inplace=True)

# %% [markdown]
# ## Problem 2: The labels are not distributed equally

# %%
merged_df.groupby("is_fake").count()
# Out:
#          index  Unnamed: 0     id  permalink  comments_count  like_count  \
# is_fake
# 0        18662       18662  18662      18662           18662       17592
# 1         3273        3273   3273       3273            3273        3124
#
#          media_type  media_url  timestamp  caption
# is_fake
# 0             18662      15218      18662    18661
# 1              3273       2391       3273     3273

# %% [markdown]
# # Split text from Hashtag

# %%
def split_caption_column(caption):
    actual_text_column = []
    hashtags_column = []

   
    for caption in caption:
        try:
            words = caption.split()

            actual_text = []
            hashtags = []

            for word in words:
                if word.startswith('#'):
                    hashtags.append(word)
                else:
                    actual_text.append(word)

            actual_text = ' '.join(actual_text)
            hashtags = ' '.join(hashtags)

            actual_text_column.append(actual_text)
            hashtags_column.append(hashtags)
        except Exception as e:
            print(caption)
            actual_text_column.append(None)
            hashtags_column.append(None)
            print(e)
    return actual_text_column, hashtags_column

actual_text_column, hashtags_column = split_caption_column(merged_df['caption'])

# Add the new columns to the DataFrame
merged_df['actual_text'] = actual_text_column
merged_df['hashtags'] = hashtags_column
# Out:
# nan
# 'float' object has no attribute 'split'

# %% [markdown]
# # Select captions containing english words

# %% [markdown]
# ### Following cell needs 10 mins to process the entries. Use ewc_df.csv instead of running it.

# %%
merged_df.drop(merged_df[merged_df['actual_text'] == ""].index, inplace=True)
merged_df.drop(merged_df[merged_df['actual_text'] == None].index, inplace=True)

# %%
saved_df=merged_df

# %%
merged_df=merged_df.reset_index()

# %%
merged_df['is_english']=""
merged_df['english_caption']=""
for row in range(len(merged_df)):
    try:

        caption= merged_df['actual_text'][row]
        cap_str=str(caption)
    
            
        try:
            
            if detect(cap_str) == 'en':
                merged_df['is_english'][row]=1
                merged_df['english_caption'][row]=cap_str
            else:
                merged_df['is_english'][row]=0
                merged_df['english_caption'][row]=None
        except Exception as e:
            print("inner:", row,e)
            merged_df['is_english'][row]=0
            merged_df['english_caption'][row]=None
    except Exception as e:
        print(e)
        print("outer:"+cap_str)
# Out:
# /tmp/ipykernel_100/3696715189.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['is_english'][row]=0
# /tmp/ipykernel_100/3696715189.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['english_caption'][row]=None
# /tmp/ipykernel_100/3696715189.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['is_english'][row]=1
# /tmp/ipykernel_100/3696715189.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['english_caption'][row]=cap_str
# /tmp/ipykernel_100/3696715189.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['is_english'][row]=0
# /tmp/ipykernel_100/3696715189.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['english_caption'][row]=None
# inner: 27 No features in text.
# inner: 45 No features in text.
# inner: 79 No features in text.
# inner: 89 No features in text.
# inner: 107 No features in text.
# inner: 114 No features in text.
# inner: 145 No features in text.
# inner: 208 No features in text.
# inner: 250 No features in text.
# inner: 257 No features in text.
# inner: 315 No features in text.
# inner: 321 No features in text.
# inner: 346 No features in text.
# inner: 380 No features in text.
# inner: 384 No features in text.
# inner: 436 No features in text.
# inner: 440 No features in text.
# inner: 441 No features in text.
# inner: 446 No features in text.
# inner: 452 No features in text.
# inner: 466 No features in text.
# inner: 533 No features in text.
# inner: 556 No features in text.
# inner: 605 No features in text.
# inner: 646 No features in text.
# inner: 673 No features in text.
# inner: 700 No features in text.
# inner: 722 No features in text.
# inner: 819 No features in text.
# inner: 858 No features in text.
# inner: 861 No features in text.
# inner: 894 No features in text.
# inner: 905 No features in text.
# inner: 943 No features in text.
# inner: 984 No features in text.
# inner: 1145 No features in text.
# inner: 1269 No features in text.
# inner: 1283 No features in text.
# inner: 1316 No features in text.
# inner: 1347 No features in text.
# inner: 1354 No features in text.
# inner: 1407 No features in text.
# inner: 1413 No features in text.
# inner: 1450 No features in text.
# inner: 1451 No features in text.
# inner: 1479 No features in text.
# inner: 1584 No features in text.
# inner: 1589 No features in text.
# inner: 1627 No features in text.
# inner: 1638 No features in text.
# inner: 1748 No features in text.
# inner: 1798 No features in text.
# inner: 1811 No features in text.
# inner: 1823 No features in text.
# inner: 1826 No features in text.
# inner: 1836 No features in text.
# inner: 1840 No features in text.
# inner: 1924 No features in text.
# inner: 1955 No features in text.
# inner: 2026 No features in text.
# inner: 2070 No features in text.
# inner: 2178 No features in text.
# inner: 2182 No features in text.
# inner: 2206 No features in text.
# inner: 2248 No features in text.
# inner: 2263 No features in text.
# inner: 2295 No features in text.
# inner: 2305 No features in text.
# inner: 2315 No features in text.
# inner: 2361 No features in text.
# inner: 2439 No features in text.
# inner: 2445 No features in text.
# inner: 2453 No features in text.
# inner: 2464 No features in text.
# inner: 2496 No features in text.
# inner: 2516 No features in text.
# inner: 2531 No features in text.
# inner: 2555 No features in text.
# inner: 2575 No features in text.
# inner: 2628 No features in text.
# inner: 2664 No features in text.
# inner: 2692 No features in text.
# inner: 2693 No features in text.
# inner: 2763 No features in text.
# inner: 2867 No features in text.
# inner: 2921 No features in text.
# inner: 2936 No features in text.
# inner: 2939 No features in text.
# inner: 3002 No features in text.
# inner: 3017 No features in text.
# inner: 3074 No features in text.
# inner: 3115 No features in text.
# inner: 3263 No features in text.
# inner: 3329 No features in text.
# inner: 3478 No features in text.
# inner: 3485 No features in text.
# inner: 3607 No features in text.
# inner: 3616 No features in text.
# inner: 3665 No features in text.
# inner: 3724 No features in text.
# inner: 3730 No features in text.
# inner: 3840 No features in text.
# inner: 3860 No features in text.
# inner: 3868 No features in text.
# inner: 3889 No features in text.
# inner: 3895 No features in text.
# inner: 3939 No features in text.
# inner: 3946 No features in text.
# inner: 4100 No features in text.
# inner: 4158 No features in text.
# inner: 4194 No features in text.
# inner: 4199 No features in text.
# inner: 4236 No features in text.
# inner: 4329 No features in text.
# inner: 4436 No features in text.
# inner: 4438 No features in text.
# inner: 4442 No features in text.
# inner: 4510 No features in text.
# inner: 4576 No features in text.
# inner: 4657 No features in text.
# inner: 4664 No features in text.
# inner: 4723 No features in text.
# inner: 4739 No features in text.
# inner: 4753 No features in text.
# inner: 4778 No features in text.
# inner: 4801 No features in text.
# inner: 4803 No features in text.
# inner: 4881 No features in text.
# inner: 4882 No features in text.
# inner: 5066 No features in text.
# inner: 5067 No features in text.
# inner: 5068 No features in text.
# inner: 5079 No features in text.
# inner: 5082 No features in text.
# inner: 5087 No features in text.
# inner: 5141 No features in text.
# inner: 5159 No features in text.
# inner: 5188 No features in text.
# inner: 5351 No features in text.
# inner: 5478 No features in text.
# inner: 5559 No features in text.
# inner: 5647 No features in text.
# inner: 5651 No features in text.
# inner: 5670 No features in text.
# inner: 5715 No features in text.
# inner: 5793 No features in text.
# inner: 5836 No features in text.
# inner: 5842 No features in text.
# inner: 5855 No features in text.
# inner: 5882 No features in text.
# inner: 5902 No features in text.
# inner: 5936 No features in text.
# inner: 5937 No features in text.
# inner: 5947 No features in text.
# inner: 5953 No features in text.
# inner: 6000 No features in text.
# inner: 6001 No features in text.
# inner: 6047 No features in text.
# inner: 6080 No features in text.
# inner: 6143 No features in text.
# inner: 6467 No features in text.
# inner: 6486 No features in text.
# inner: 6565 No features in text.
# inner: 6643 No features in text.
# inner: 6706 No features in text.
# inner: 6748 No features in text.
# inner: 6852 No features in text.
# inner: 6880 No features in text.
# inner: 6914 No features in text.
# inner: 6970 No features in text.
# inner: 6975 No features in text.
# inner: 6976 No features in text.
# inner: 6978 No features in text.
# inner: 6994 No features in text.
# inner: 7015 No features in text.
# inner: 7055 No features in text.
# inner: 7137 No features in text.
# inner: 7241 No features in text.
# inner: 7319 No features in text.
# inner: 7431 No features in text.
# inner: 7531 No features in text.
# inner: 7534 No features in text.
# inner: 7579 No features in text.
# inner: 7585 No features in text.
# inner: 7664 No features in text.
# inner: 7694 No features in text.
# inner: 7715 No features in text.
# inner: 7733 No features in text.
# inner: 7748 No features in text.
# inner: 7919 No features in text.
# inner: 7935 No features in text.
# inner: 8054 No features in text.
# inner: 8146 No features in text.
# inner: 8339 No features in text.
# inner: 8371 No features in text.
# inner: 8601 No features in text.
# inner: 8603 No features in text.
# inner: 8646 No features in text.
# inner: 8655 No features in text.
# inner: 8779 No features in text.
# inner: 8789 No features in text.
# inner: 8805 No features in text.
# inner: 8849 No features in text.
# inner: 8916 No features in text.
# inner: 9087 No features in text.
# inner: 9255 No features in text.
# inner: 9306 No features in text.
# inner: 9344 No features in text.
# inner: 9364 No features in text.
# inner: 9388 No features in text.
# inner: 9397 No features in text.
# inner: 9427 No features in text.
# inner: 9445 No features in text.
# inner: 9511 No features in text.
# inner: 9536 No features in text.
# inner: 9596 No features in text.
# inner: 9608 No features in text.
# inner: 9626 No features in text.
# inner: 9670 No features in text.
# inner: 9702 No features in text.
# inner: 9746 No features in text.
# inner: 9777 No features in text.
# inner: 9909 No features in text.
# inner: 9911 No features in text.
# inner: 9913 No features in text.
# inner: 9923 No features in text.
# inner: 9929 No features in text.
# inner: 10025 No features in text.
# inner: 10037 No features in text.
# inner: 10063 No features in text.
# inner: 10072 No features in text.
# inner: 10143 No features in text.
# inner: 10164 No features in text.
# inner: 10257 No features in text.
# inner: 10314 No features in text.
# inner: 10426 No features in text.
# inner: 10485 No features in text.
# inner: 10558 No features in text.
# inner: 10578 No features in text.
# inner: 10608 No features in text.
# inner: 10650 No features in text.
# inner: 10821 No features in text.
# inner: 10921 No features in text.
# inner: 11010 No features in text.
# inner: 11019 No features in text.
# inner: 11049 No features in text.
# inner: 11094 No features in text.
# inner: 11146 No features in text.
# inner: 11148 No features in text.
# inner: 11165 No features in text.
# inner: 11182 No features in text.
# inner: 11249 No features in text.
# inner: 11405 No features in text.
# inner: 11478 No features in text.
# inner: 11670 No features in text.
# inner: 11839 No features in text.
# inner: 11903 No features in text.
# inner: 11911 No features in text.
# inner: 12011 No features in text.
# inner: 12018 No features in text.
# inner: 12029 No features in text.
# inner: 12161 No features in text.
# inner: 12168 No features in text.
# inner: 12169 No features in text.
# inner: 12289 No features in text.
# inner: 12322 No features in text.
# inner: 12532 No features in text.
# inner: 12591 No features in text.
# inner: 12592 No features in text.
# inner: 12723 No features in text.
# inner: 12943 No features in text.
# inner: 13014 No features in text.
# inner: 13089 No features in text.
# inner: 13094 No features in text.
# inner: 13095 No features in text.
# inner: 13121 No features in text.
# inner: 13139 No features in text.
# inner: 13207 No features in text.
# inner: 13218 No features in text.
# inner: 13638 No features in text.
# inner: 13644 No features in text.
# inner: 13657 No features in text.
# inner: 13733 No features in text.
# inner: 13757 No features in text.
# inner: 13818 No features in text.
# inner: 13854 No features in text.
# inner: 13867 No features in text.
# inner: 13868 No features in text.
# inner: 13990 No features in text.
# inner: 13992 No features in text.
# inner: 13993 No features in text.
# inner: 14108 No features in text.
# inner: 14235 No features in text.
# inner: 14514 No features in text.
# inner: 14555 No features in text.
# inner: 14565 No features in text.
# inner: 14722 No features in text.
# inner: 14893 No features in text.
# inner: 14969 No features in text.
# inner: 15026 No features in text.
# inner: 15107 No features in text.
# inner: 15126 No features in text.
# inner: 15144 No features in text.
# inner: 15194 No features in text.
# inner: 15262 No features in text.
# inner: 15268 No features in text.
# inner: 15287 No features in text.
# inner: 15367 No features in text.
# inner: 15394 No features in text.
# inner: 15441 No features in text.
# inner: 15544 No features in text.
# inner: 15597 No features in text.
# inner: 15639 No features in text.
# inner: 15715 No features in text.
# inner: 15773 No features in text.
# inner: 15793 No features in text.
# inner: 15853 No features in text.
# inner: 15916 No features in text.
# inner: 15934 No features in text.
# inner: 15943 No features in text.
# inner: 15998 No features in text.
# inner: 16081 No features in text.
# inner: 16127 No features in text.
# inner: 16138 No features in text.
# inner: 16201 No features in text.
# inner: 16271 No features in text.
# inner: 16342 No features in text.
# inner: 16399 No features in text.
# inner: 16402 No features in text.
# inner: 16445 No features in text.
# inner: 16553 No features in text.
# inner: 16573 No features in text.
# inner: 16735 No features in text.
# inner: 16789 No features in text.
# inner: 16946 No features in text.
# inner: 17153 No features in text.
# inner: 17327 No features in text.
# inner: 17802 No features in text.
# inner: 17975 No features in text.
# inner: 18035 No features in text.
# inner: 18085 No features in text.
# inner: 18099 No features in text.
# inner: 18104 No features in text.
# inner: 18156 No features in text.
# inner: 18325 No features in text.
# inner: 18344 No features in text.
# inner: 18427 No features in text.
# inner: 18715 No features in text.
# inner: 18790 No features in text.
# inner: 18833 No features in text.
# inner: 18876 No features in text.
# inner: 19260 No features in text.
# inner: 19293 No features in text.
# inner: 19340 No features in text.
# inner: 19378 No features in text.
# inner: 19455 No features in text.
# inner: 19540 No features in text.
# inner: 19923 No features in text.
# inner: 20027 No features in text.
# inner: 20105 No features in text.
# inner: 20136 No features in text.
# inner: 20144 No features in text.
# inner: 20151 No features in text.
# inner: 20227 No features in text.
# inner: 20254 No features in text.
# inner: 20280 No features in text.
# inner: 20363 No features in text.
# inner: 20426 No features in text.
# inner: 20495 No features in text.
# inner: 20507 No features in text.
# inner: 20620 No features in text.
# inner: 20891 No features in text.
# inner: 20981 No features in text.
# inner: 21006 No features in text.

# %%
#Remove non-english rows
merged_df.drop(merged_df[merged_df['is_english'] == 0].index, inplace=True)
#reindexing because of dropped rows
merged_df=merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#       level_0   index Unnamed: 0                 id  \
# 0           1       1          1  17993509183855559
# 1           5       5          5  18005295199826313
# 2           9       9          9  18011517661655428
# 3          10      10         10  18009993862606500
# 4          12      12         12  17982058046476888
# ...       ...     ...        ...                ...
# 8520   195551  113695          3  18185951629272070
# 8521   195552  113696          4  17983389545190690
# 8522   195553  113697          5  17970893624266885
# 8523   195559  113703         11  18010682851736514
# 8524   195560  113704         12  17922047183647983
#
#                                         permalink  comments_count  like_count  \
# 0        https://www.instagram.com/p/CtWQW2WvQqA/             1.0         8.0
# 1       https://www.instagram.com/tv/CtWQRtJu02n/             0.0         0.0
# 2     https://www.instagram.com/reel/CtWOR7gAalj/             0.0        23.0
# 3     https://www.instagram.com/reel/CtWQI5-BcDn/             7.0       164.0
# 4        https://www.instagram.com/p/CtWQNsYSZ6w/             0.0         0.0
# ...                                           ...             ...         ...
# 8520  https://www.instagram.com/reel/Ct1lttSg3pT/             0.0         0.0
# 8521     https://www.instagram.com/p/Ct1luLdLvct/             0.0         0.0
# 8522  https://www.instagram.com/reel/Ct1lXfugsWg/             0.0         1.0
# 8523     https://www.instagram.com/p/Ct1kzAzLcSm/             0.0         0.0
# 8524     https://www.instagram.com/p/Ct1kvn7LMuo/             0.0         NaN
#
#           media_type                                          media_url  \
# 0              IMAGE  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 1              VIDEO  https://video-iad3-2.cdninstagram.com/v/t42.17...
# 2              VIDEO  https://scontent-iad3-1.cdninstagram.com/o1/v/...
# 3              VIDEO  https://scontent-iad3-1.cdninstagram.com/o1/v/...
# 4     CAROUSEL_ALBUM                                                NaN
# ...              ...                                                ...
# 8520           VIDEO  https://scontent-iad3-1.cdninstagram.com/o1/v/...
# 8521           IMAGE  https://scontent-iad3-2.cdninstagram.com/v/t51...
# 8522           VIDEO  https://scontent-iad3-1.cdninstagram.com/o1/v/...
# 8523           IMAGE  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 8524           IMAGE  https://scontent-iad3-2.cdninstagram.com/v/t51...
#
#                      timestamp  \
# 0     2023-06-11T11:04:26+0000
# 1     2023-06-11T11:03:46+0000
# 2     2023-06-11T11:03:25+0000
# 3     2023-06-11T11:03:25+0000
# 4     2023-06-11T11:03:11+0000
# ...                        ...
# 8520  2023-06-23T15:08:46+0000
# 8521  2023-06-23T15:07:34+0000
# 8522  2023-06-23T15:07:21+0000
# 8523  2023-06-23T14:59:30+0000
# 8524  2023-06-23T14:59:02+0000
#
#                                                 caption is_fake  \
# 0     Pacific Joint Space Facility lunarcor_ sister ...       0
# 1             #news Neil Oliver: "I say they're lying".       0
# 2     What’s your thoughts on Chatgpt ?\n#chatgpt #n...       0
# 3     Follow nerdrudransh for more fax 🤨\n\n#adipuru...       0
# 4     Follow more new update\n.\n.\n.\n.\n.\n.\n.\n#...       0
# ...                                                 ...     ...
# 8520  Official Answer… by mattwalshblog \n**********...       1
# 8521  Fake Fact: Sloths have a 5th leg that is only ...       1
# 8522  Propaganda is so effective it’s fascinating 🖤\...       1
# 8523  Biden sniffin’ a troon 👀\n\n******************...       1
# 8524  Same mistakes won't be made, promises a spokes...       1
#
#                                             actual_text  \
# 0     Pacific Joint Space Facility lunarcor_ sister ...
# 1                   Neil Oliver: "I say they're lying".
# 2                     What’s your thoughts on Chatgpt ?
# 3                    Follow nerdrudransh for more fax 🤨
# 4                  Follow more new update . . . . . . .
# ...                                                 ...
# 8520  Official Answer… by mattwalshblog ************...
# 8521  Fake Fact: Sloths have a 5th leg that is only ...
# 8522      Propaganda is so effective it’s fascinating 🖤
# 8523       Biden sniffin’ a troon 👀 *******************
# 8524  Same mistakes won't be made, promises a spokes...
#
#                                                hashtags is_english  \
# 0     #pacificjointspacefacility #johnmoody #competi...          1
# 1                                                 #news          1
# 2             #chatgpt #news #india #m&m #new #thoughts          1
# 3     #adipurush #movie #cinema #bollywood #actor #p...          1
# 4     #currentaffair #gk #ssc #upsc #ssccgl #current...          1
# ...                                                 ...        ...
# 8520  #WeAreBreitbart #TheEpochTimes #Republicans #D...          1
# 8521  #fact #factsdaily #dailyfacts #aiart #sloths #...          1
# 8522  #propaganda #news #fakenews #joerogan #riseaga...          1
# 8523  #WeAreBreitbart #TheEpochTimes #Republicans #D...          1
# 8524  #comedy #satire #humor #news #breakingnews #bo...          1
#
#                                         english_caption
# 0     Pacific Joint Space Facility lunarcor_ sister ...
# 1                   Neil Oliver: "I say they're lying".
# 2                     What’s your thoughts on Chatgpt ?
# 3                    Follow nerdrudransh for more fax 🤨
# 4                  Follow more new update . . . . . . .
# ...                                                 ...
# 8520  Official Answer… by mattwalshblog ************...
# 8521  Fake Fact: Sloths have a 5th leg that is only ...
# 8522      Propaganda is so effective it’s fascinating 🖤
# 8523       Biden sniffin’ a troon 👀 *******************
# 8524  Same mistakes won't be made, promises a spokes...
#
# [8525 rows x 16 columns]

# %% [markdown]
# # Remove symbols from other alphabets

# %%
for row in range(len(merged_df)):
    if row <= len(merged_df):
        english_caption=""
        caption_str=str(merged_df['english_caption'][row] )
        words= caption_str.split()
        for word in words:
            if re.match(r'^[a-zA-Z0-9,_]+$', word):
                english_caption += ' '+word

        merged_df['english_caption'][row] = english_caption
# Out:
# /tmp/ipykernel_100/666922674.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['english_caption'][row] = english_caption

# %%
merged_df.dropna(subset=['english_caption'], inplace=True)
merged_df=merged_df.reset_index(drop=True)

# %% [markdown]
# # NLP

# %% [markdown]
# ### Pre-processing and tokenizing

# %%
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def preprocess_caption(caption):
    # Tokenize the caption into individual words
    tokens = word_tokenize(caption)
    
    # Convert tokens to lowercase
    tokens = [token.lower() for token in tokens]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    # Join tokens back into a processed caption
    processed_caption = ' '.join(tokens)
    
    return processed_caption

# %%
merged_df['preprocessed_caption'] = ""
caption=""
for row in range(len(merged_df)):
    try:
        caption= str(merged_df['english_caption'][row])
        merged_df['preprocessed_caption'][row]=preprocess_caption(caption)
    except Exception as e:
        print(e, caption)
# Out:
# /tmp/ipykernel_100/4066863461.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['preprocessed_caption'][row]=preprocess_caption(caption)

# %%
merged_df
# Out:
#       level_0   index Unnamed: 0                 id  \
# 0           1       1          1  17993509183855559
# 1           5       5          5  18005295199826313
# 2           9       9          9  18011517661655428
# 3          10      10         10  18009993862606500
# 4          12      12         12  17982058046476888
# ...       ...     ...        ...                ...
# 8520   195551  113695          3  18185951629272070
# 8521   195552  113696          4  17983389545190690
# 8522   195553  113697          5  17970893624266885
# 8523   195559  113703         11  18010682851736514
# 8524   195560  113704         12  17922047183647983
#
#                                         permalink  comments_count  like_count  \
# 0        https://www.instagram.com/p/CtWQW2WvQqA/             1.0         8.0
# 1       https://www.instagram.com/tv/CtWQRtJu02n/             0.0         0.0
# 2     https://www.instagram.com/reel/CtWOR7gAalj/             0.0        23.0
# 3     https://www.instagram.com/reel/CtWQI5-BcDn/             7.0       164.0
# 4        https://www.instagram.com/p/CtWQNsYSZ6w/             0.0         0.0
# ...                                           ...             ...         ...
# 8520  https://www.instagram.com/reel/Ct1lttSg3pT/             0.0         0.0
# 8521     https://www.instagram.com/p/Ct1luLdLvct/             0.0         0.0
# 8522  https://www.instagram.com/reel/Ct1lXfugsWg/             0.0         1.0
# 8523     https://www.instagram.com/p/Ct1kzAzLcSm/             0.0         0.0
# 8524     https://www.instagram.com/p/Ct1kvn7LMuo/             0.0         NaN
#
#           media_type                                          media_url  \
# 0              IMAGE  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 1              VIDEO  https://video-iad3-2.cdninstagram.com/v/t42.17...
# 2              VIDEO  https://scontent-iad3-1.cdninstagram.com/o1/v/...
# 3              VIDEO  https://scontent-iad3-1.cdninstagram.com/o1/v/...
# 4     CAROUSEL_ALBUM                                                NaN
# ...              ...                                                ...
# 8520           VIDEO  https://scontent-iad3-1.cdninstagram.com/o1/v/...
# 8521           IMAGE  https://scontent-iad3-2.cdninstagram.com/v/t51...
# 8522           VIDEO  https://scontent-iad3-1.cdninstagram.com/o1/v/...
# 8523           IMAGE  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 8524           IMAGE  https://scontent-iad3-2.cdninstagram.com/v/t51...
#
#                      timestamp  \
# 0     2023-06-11T11:04:26+0000
# 1     2023-06-11T11:03:46+0000
# 2     2023-06-11T11:03:25+0000
# 3     2023-06-11T11:03:25+0000
# 4     2023-06-11T11:03:11+0000
# ...                        ...
# 8520  2023-06-23T15:08:46+0000
# 8521  2023-06-23T15:07:34+0000
# 8522  2023-06-23T15:07:21+0000
# 8523  2023-06-23T14:59:30+0000
# 8524  2023-06-23T14:59:02+0000
#
#                                                 caption is_fake  \
# 0     Pacific Joint Space Facility lunarcor_ sister ...       0
# 1             #news Neil Oliver: "I say they're lying".       0
# 2     What’s your thoughts on Chatgpt ?\n#chatgpt #n...       0
# 3     Follow nerdrudransh for more fax 🤨\n\n#adipuru...       0
# 4     Follow more new update\n.\n.\n.\n.\n.\n.\n.\n#...       0
# ...                                                 ...     ...
# 8520  Official Answer… by mattwalshblog \n**********...       1
# 8521  Fake Fact: Sloths have a 5th leg that is only ...       1
# 8522  Propaganda is so effective it’s fascinating 🖤\...       1
# 8523  Biden sniffin’ a troon 👀\n\n******************...       1
# 8524  Same mistakes won't be made, promises a spokes...       1
#
#                                             actual_text  \
# 0     Pacific Joint Space Facility lunarcor_ sister ...
# 1                   Neil Oliver: "I say they're lying".
# 2                     What’s your thoughts on Chatgpt ?
# 3                    Follow nerdrudransh for more fax 🤨
# 4                  Follow more new update . . . . . . .
# ...                                                 ...
# 8520  Official Answer… by mattwalshblog ************...
# 8521  Fake Fact: Sloths have a 5th leg that is only ...
# 8522      Propaganda is so effective it’s fascinating 🖤
# 8523       Biden sniffin’ a troon 👀 *******************
# 8524  Same mistakes won't be made, promises a spokes...
#
#                                                hashtags is_english  \
# 0     #pacificjointspacefacility #johnmoody #competi...          1
# 1                                                 #news          1
# 2             #chatgpt #news #india #m&m #new #thoughts          1
# 3     #adipurush #movie #cinema #bollywood #actor #p...          1
# 4     #currentaffair #gk #ssc #upsc #ssccgl #current...          1
# ...                                                 ...        ...
# 8520  #WeAreBreitbart #TheEpochTimes #Republicans #D...          1
# 8521  #fact #factsdaily #dailyfacts #aiart #sloths #...          1
# 8522  #propaganda #news #fakenews #joerogan #riseaga...          1
# 8523  #WeAreBreitbart #TheEpochTimes #Republicans #D...          1
# 8524  #comedy #satire #humor #news #breakingnews #bo...          1
#
#                                         english_caption  \
# 0      Pacific Joint Space Facility lunarcor_ sister...
# 1                                              Neil say
# 2                              your thoughts on Chatgpt
# 3                      Follow nerdrudransh for more fax
# 4                                Follow more new update
# ...                                                 ...
# 8520                          Official by mattwalshblog
# 8521   Fake Sloths have a 5th leg that is only visib...
# 8522             Propaganda is so effective fascinating
# 8523                                      Biden a troon
# 8524   Same mistakes be made, promises a Right after...
#
#                                    preprocessed_caption
# 0     pacific joint space facility lunarcor_ sister ...
# 1                                              neil say
# 2                                       thought chatgpt
# 3                               follow nerdrudransh fax
# 4                                     follow new update
# ...                                                 ...
# 8520                             official mattwalshblog
# 8521  fake sloth 5th leg visible uv spectrum , thus ...
# 8522                   propaganda effective fascinating
# 8523                                        biden troon
# 8524  mistake made , promise right making announceme...
#
# [8525 rows x 17 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4c8af7b1-f3b8-45ab-bbdc-6a32713107d1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
