# %% [markdown]
# # Data Requesting and Streaming

# %% [markdown]
# For requesting the posts of a hashtag, which are required for the project, the following are required:

# %% [markdown]
# - Facebook developer account

# %% [markdown]
# - A business Page

# %% [markdown]
# - Instagram Business account

# %% [markdown]
# - A custom App created through the Facebook development interface, which is linked to the three aforementioned bulletpoints

# %% [markdown]
# The following code is used for streaming the posts of a hashtag on instagram. To be able to run this code, the access token needs to be prepared by adding the following permissions:

# %% [markdown]
# ![Picture title](docs/permissions.png)

# %% [markdown]
#  Afterwards, after linking the page to the app and the instagram business account to the page, the user can obtain the linked instagram accounts of the page by running the following request with the page API token:

# %% [markdown]
# https://graph.facebook.com/v17.0/me?fields=connected_instagram_account

# %% [markdown]
# The next step, while using the same API, is querying for the required hashtag id. Example:

# %% [markdown]
# graph.facebook.com/ig_hashtag_search
# ?user_id="obtained from the last request"&q="name of the hashtag"

# %% [markdown]
# After obtaining the hashtag ID, the recent posts are obtained with the following request:

# %% [markdown]
# graph.facebook.com/"Hashtag ID obtained from last query"/recent_media?access_token="ENTER_ACCESS_TOKEN"&fields=id,permalink,comments_count,like_count,media_type,media_url,timestamp,caption&user_id="ENTER_INSTAGRAM_ID&limit=50'

# %% [markdown]
# Such queries are also possible for top media by replacing "recent_media" with "top_media"

# %%
import json
import datetime
import pandas as pd
import time
import requests

# %%
# This is a Python blockimport requests

def getCreds() :

	creds = dict() # dictionary to hold everything
	creds['access_token'] = 'ENTER_ACCESS_TOKEN' # client id from facebook app IG Graph API Test
	creds['client_secret'] = 'ENTER_CLIENT_SECRET' # client secret from facebook app
	creds['graph_domain'] = 'https://graph.facebook.com/' # base domain for api calls
	creds['graph_version'] = 'v17.0' # version of the api we are hitting
	creds['endpoint_base'] = creds['graph_domain'] + creds['graph_version'] + '/' # base endpoint with domain and version
	creds['debug'] = 'no' # debug mode for api call
	creds['page_id'] = 'ENTER_PAGE_ID' # users page id after running the "get_user_facebook_page.py"
	creds['instagram_account_id'] = 'ENTER_ACCOUNT_ID' # users instagram account id after running the "get_user_instagram_page.py"
	creds['ig_username'] = 'ENTER_IG_USERNAME' # ig username to get details

	return creds


def makeApiCall( url, endpointParams, debug = 'no' ) :
	data = requests.get( url, endpointParams ) # make get request
	response = dict() # hold response info
	response['url'] = url # url we are hitting
	response['endpoint_params'] = endpointParams #parameters for the endpoint
	response['endpoint_params_pretty'] = json.dumps( endpointParams, indent = 4 ) # pretty print for cli
	response['json_data'] = json.loads( data.content ) # response data from the api
	response['json_data_pretty'] = json.dumps( response['json_data'], indent = 4 ) # pretty print for cli
    
	return response # get and return content

def displayApiCallData( response ) :
	""" Print out to cli response from api call """

	print ("\nURL: ") # title
	print (response['url']) # display url hit
	print ("\nEndpoint Params: ") # title
	print (response['endpoint_params_pretty']) # display params passed to the endpoint
	print ("\nResponse: ") # title
	print (response['json_data_pretty']) # make look pretty for cli

# %%
def debugAccessToken( params ) :

	endpointParams = dict() # parameter to send to the endpoint
	endpointParams['input_token'] = params['access_token'] # input token is the access token
	endpointParams['access_token'] = params['access_token'] # access token to get debug info on

	url = params['graph_domain'] + '/debug_token' # endpoint url

	return makeApiCall( url, endpointParams, params['debug'] ) # make the api call

params = getCreds() # get creds
params['debug'] = 'yes' # set debug
response = debugAccessToken( params ) # hit the api for some data!

print ("\nData Access Expires at: ") # label
print (datetime.datetime.fromtimestamp( response['json_data']['data']['data_access_expires_at'] )) # display out when the token expires

print ("\nToken Expires at: ") # label
print (datetime.datetime.fromtimestamp( response['json_data']['data']['expires_at'] )) # display out when the token expires
# Out:
# Data Access Expires at:
# 2023-09-21 14:45:57
#
# Token Expires at:
# 2023-08-22 14:22:45

# %%
def getLongLivedAccessToken( params ) :

	endpointParams = dict() # parameter to send to the endpoint
	endpointParams['grant_type'] = 'fb_exchange_token' # tell facebook we want to exchange token
	endpointParams['client_id'] = "ENTER_CLIENT_ID" # client id from facebook app
	endpointParams['client_secret'] = params['client_secret'] # client secret from facebook app
	endpointParams['fb_exchange_token'] = params['access_token'] # access token to get exchange for a long lived token

	url = params['endpoint_base'] + 'oauth/access_token?' # endpoint url

	return makeApiCall( url, endpointParams, params['debug'] ) # make the api call

params = getCreds() # get creds
params['debug'] = 'yes' # set debug
response = getLongLivedAccessToken( params ) # hit the api for some data!

print ("\n ---- ACCESS TOKEN INFO ----\n") # section header
print ("Access Token:")  # label
print (response['json_data']['access_token']) # display access token
# Out:
#  ---- ACCESS TOKEN INFO ----
#
# Access Token:
# EAAETCS5I9KkBANFIqMkG6jBtxpabq5LbnpZBhe3riXQWaHwGCxNN0GIjzYbmGAmPydKlvndGW2aCwoF7siJfbryQP3mXFvCZB48jWCVvUlsLL5nDI0zvuKo3ZCwX5oCg0kMegKB6OoR29x8FQkYJUGk3EBO68cJUj8Mx3uiIvbZCH78988b4

# %%
params = getCreds() # get creds

# %%
def getHashtagInfo( params, ig_hashtag ) :
                        endpointParams = dict() # parameter to send to the endpoint
                        endpointParams['user_id'] = params['instagram_account_id'] # user id making request
                        endpointParams['q'] = ig_hashtag # hashtag name
                        endpointParams['fields'] = 'id,name' # fields to get back
                        endpointParams['access_token'] = params['access_token'] # access token

                        url = params['endpoint_base'] + 'ig_hashtag_search' # endpoint url

                        return makeApiCall( url, endpointParams, params['debug'] )
hashtag_id = getHashtagInfo( params, "fakenews" )['json_data']['data'][0]['id']

# %%
hashtag_id
# Out:
# '17843857336037659'

# %%
def getNewsPosts( params ) :

        endpointParams = dict() # parameter to send to the endpoint
        endpointParams['user_id'] = params['instagram_account_id'] # user id making request
        endpointParams['fields'] = 'id,permalink,comments_count,like_count,media_type,media_url,timestamp,caption' # fields to get back
        endpointParams['access_token'] = params['access_token'] # access token
        
        
        params['hashtag_id'] = hashtag_id #"example 17843857336037659"
        
        params['type'] = 'recent_media?fields=comments_count,caption,media_url' # set call to get top media for hashtag

        url = params['endpoint_base'] + params['hashtag_id'] + '/' + params['type'] # endpoint url

        return makeApiCall( url, endpointParams, params['debug'] ) # make the api call

params = getCreds() # get creds
response = getNewsPosts( params ) # get users media from the api


print (response['json_data']['data'][0])
# Out:
# {'id': '17999660677904260', 'permalink': 'https://www.instagram.com/reel/Ct3zPgsLwWm/', 'comments_count': 0, 'like_count': 0, 'media_type': 'VIDEO', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/o1/v/t16/f1/m82/E64BF0CAFBFD2ECB9682F92E86C4419F_video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6InZ0c192b2RfdXJsZ2VuLjcyMC5jbGlwcyJ9&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=108&vs=6420930774640143_409971131&_nc_vs=%3D%3D&ccb=9-4&oh=00_AfBkOSsZqDqD5A1mmy3YazaGmwrGqWvOP9466EsawlC7Aw&oe=6498B885&_nc_sid=1d576d&_nc_rid=1e7d8027bb', 'timestamp': '2023-06-24T11:45:19+0000', 'caption': 'FactCheck - The Viral Image Does Not Show The Wedding Ceremony Of Nirmala Sitharaman’s Daughter\n\nVerify it with factcrescendoindia\n\n✅Whatsapp FactLine: 9049053770\n\n#Factcrescendo #Factcheck #Factchecking #BraketheFake #Fakenews #headlines #todaysnews #newsreporter #updatenews #newstoday #newsoftheday #newsupdate #latestnews #dailynews #breakingnews #reels #trendinng #india  #daughter #NirmalaSitharaman #PrasidhKrishna #wedding FCAnchorFactCheck - The Viral Image Does Not Show The Wedding Ceremony Of Nirmala Sitharaman’s Daughter\n\nVerify it with factcrescendoindia\n\n✅Whatsapp FactLine: 9049053770\n\n#Factcrescendo #Factcheck #Factchecking #BraketheFake #Fakenews #headlines #todaysnews #newsreporter #updatenews #newstoday #newsoftheday #newsupdate #latestnews #dailynews #breakingnews #reels #trendinng #india  #daughter #NirmalaSitharaman #PrasidhKrishna #wedding FCAnchor'}

# %%
import time
import random

# %%
def postsLooper(url,count, posts):
    if count <1000:
        #time.sleep(random.uniform(1, 3))

        print(count)
        print(len(posts))
        response=makeApiCall(url,"","")
        
        try:
            print(response)
            next_page= response['json_data']['paging']['next']
        except Exception as e:
            print(e) 
            print(response)
            return posts
        print("Adding posts from batch")
        try:
            for post in response["json_data"]["data"]:
                posts.append(post)
        except Exception as e:
            print(e)
            print(response)
            
            return posts

    if count == 1000:
        return posts
    return postsLooper(next_page,count+1,posts)

# %% [markdown]
# Begins loop for obtaining posts. The loop iterates after every request and continues requesting based on the page links obtained in the json response.

# %%
posts3= postsLooper('https://graph.facebook.com/v17.0/'+hashtag_id+'/top_media?access_token=ENTER_ACCESS_TOKEN&fields=id%2Cpermalink%2Ccomments_count%2Clike_count%2Cmedia_type%2Cmedia_url%2Ctimestamp%2Ccaption&user_id=17841460143570104&limit=50',0,[])
# Out:
# aid,#prayfortrump,#prayforpresidenttrump,#Jesus,#pray,#prophetic,#prayfordonaldjtrump,#God,#Trumpwon,#trump2024,#trumpwon,#2000mules,#gop,#fakenews,#djt,#marjorietaylorgreene, #israel #trumpets,#trump #twitter #donaldtrump #cpac, #presidenttrumpnews,#elonmusk #kevinmccarthy,#mattgaetz, #karilake"\n        },\n        {\n            "id": "18001158424884191",\n            "permalink": "https://www.instagram.com/p/Ctuz7rDMp-M/",\n            "comments_count": 220,\n            "like_count": 1647,\n            "media_type": "IMAGE",\n            "media_url": "https://scontent-iad3-2.cdninstagram.com/v/t39.30808-6/355489936_654996886668595_2416544798251008753_n.jpg?_nc_cat=103&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=ngzOy8lCXbkAX99kT8E&_nc_ht=scontent-iad3-2.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfD_JsBeT0Je25C6Z6h9LqKQwGRMrAa9oXib4o_1jRHPlA&oe=649BC004",\n            "timestamp": "2023-06-20T23:57:04+0000",\n            "caption": "PL DAS FAKE NEWS | O ministro Alexandre de Moraes, do Supremo Tribunal Federal, voltou a defender nesta ter\\u00e7a-feira, 20, a regulamenta\\u00e7\\u00e3o das redes sociais destacando como as big techs \'manipularam informa\\u00e7\\u00f5es\' na semana em que foi votado o regime de urg\\u00eancia do chamado PL das fake news.\\n\\n\\"Para se ver o poder de manipula\\u00e7\\u00e3o. Ali foi utilizado para auto favorecimento. Em outra oportunidade pode ser novamente instrumentalizado para o ataque \\u00e0 democracia. E eventualmente pode ser utilizado para ataques individuais\\", afirmou.\\n\\nDurante palestra no F\\u00f3rum Internacional Justi\\u00e7a e Inova\\u00e7\\u00e3o, promovido pelo Supremo em parceria com o Tribunal Superior do Trabalho e o Conselho Nacional de Justi\\u00e7a, o relator do inqu\\u00e9rito das mil\\u00edcias digitais pregou que as redes sociais precisam de mais transpar\\u00eancia crit\\u00e9rios, al\\u00e9m de \'respeitar os direitos fundamentais\'.\\n\\nAlexandre de Moraes voltou a indicar que \'tudo que vale no mundo real\' deve valer no virtual. \\"N\\u00e3o \\u00e9 poss\\u00edvel que continuemos a fechar os olhos e achar que \\u00e9 normal as pessoas defenderem discurso de \\u00f3dio nas redes como se fosse normal. Vamos transformar as redes sociais no esgoto da humanidade, desrespeitar as pessoas sem nenhuma responsabiliza\\u00e7\\u00e3o? Se voc\\u00ea \\u00e9 um miliciano digital e tem a coragem de ofender pessoas que tenha coragem de se identificar\\", destacou.\\n\\nSaIba mais em JC.COM.BR (Foto: T\\u00e2nia R\\u00eago/ Ag\\u00eancia Brasil e Pexels) #cc #Moraes #PL #FakeNews"\n        },\n        {\n            "id": "18062246950393411",\n            "permalink": "https://www.instagram.com/p/CtccOcXyN9A/",\n            "comments_count": 3,\n            "like_count": 319,\n            "media_type": "IMAGE",\n            "media_url": "https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/353479151_293634523005288_1865768604276225172_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=Gbzogq2MPuwAX8Qzxcy&_nc_oc=AQlXVJSqogjmMCRXHFg6jwjzrzaqICtf2UdW-8LAYby4VnVKygM28b-4KEerGuEOXiM&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfDy3UZZ9lwoIdwtHyLUxYIIYan0LoHYkdVwN8HikRw2lg&oe=649BF3CB",\n            "timestamp": "2023-06-13T20:43:35+0000",\n            "caption": "Truth \\ud83d\\udca3 \\n\\n#freedomseeker #truthseeker #truthseekers #wakeup #wakeupsheeple #spirituality #questioneverything #conspiracytheory #qanon #higherconsciousness #spiritualawakening #wwg1wga #thegreatawakening #seekthetruth #redpill #doyourownresearch #truthbetold #knowledgeispower #freethinkers #fakenews #wakeuppeople #spiritualgrowth #thinkforyourself #freethinker"\n        },\n        {\n            "id": "18146403412288130",\n            "permalink": "https://www.instagram.com/p/CtucTdktl86/",\n            "comments_count": 1557,\n            "like_count": 30439,\n            "media_type": "CAROUSEL_ALBUM",\n            "timestamp": "2023-06-20T20:30:36+0000",\n            "caption": "VERIFICA\\u0 ...
# Adding posts from batch
# 996
# 47854
# {'url': 'https://graph.facebook.com/v17.0/17843857336037659/top_media?access_token=EAAETCS5I9KkBANFIqMkG6jBtxpabq5LbnpZBhe3riXQWaHwGCxNN0GIjzYbmGAmPydKlvndGW2aCwoF7siJfbryQP3mXFvCZB48jWCVvUlsLL5nDI0zvuKo3ZCwX5oCg0kMegKB6OoR29x8FQkYJUGk3EBO68cJUj8Mx3uiIvbZCH78988b4&fields=id%2Cpermalink%2Ccomments_count%2Clike_count%2Cmedia_type%2Cmedia_url%2Ctimestamp%2Ccaption&user_id=17841460143570104&limit=50&after=NTE0OThlODU2MjY3NDJkMzkyYmY0MzM2NjNjYTNhM2EZD', 'endpoint_params': '', 'endpoint_params_pretty': '""', 'json_data': {'data': [{'id': '17980966259246672', 'permalink': 'https://www.instagram.com/p/Ct1Gcbttd7T/', 'comments_count': 9, 'like_count': 80, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/355399860_188375624202589_6267760928383452469_n.heic?stp=dst-jpg&_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=XUKRrMiVV78AX-ZTZfA&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfBZpeWwVMgzDz07d3JMKtHdageKfnsMcYZb6Dc5L3ONeA&oe=649B4140', 'timestamp': '2023-06-23T10:34:16+0000', 'caption': 'Extremadura es como un clon de Andalucía. Los que ahora salen y salieron, diciendo que los cuarenta años de Franco y bla bla bla bla. Creo que si no me fallan los cálculos, el PSOE estuvo en Andalucia cuarenta años..o treinta y ocho ¿porqué? pueden mirar la famosa y única Ley de las muchas discriminatorias, llamada PER...un invento de Felipe González, donde en toda España, los jornaleros tenían un privilegio. Luego vino vino Zapatero en el dos mil ocho y se cargó el art 14 "todos los españoles somos iguales sin distinción..."con su Ley de VG.\n\nAhora la veleta rubia, se dedica en plan progres, a hacer y poner a parir a otro partido, llamándolos de todo, simplemente por la razón de sus ideales, bastante igualitarios sin chiringuitos ni distinciones. Pero la avaricia de creerse progre azul, prefiere pactar con los desechos de las elecciones. Aún sabiendo que habrá nuevas...\n\nPero mientras, se dedica como buena yegua a trotar y cabalgar, en el populismo rancio de ideales de colores e ideologías de minorías, cultura woke, etcétera\n\nOtra Blancanieves de Disney versión actual...\n\nbuenos diassss... fachassssss!!!\n\n#prohibido\n#añonuevo\n#bar\n#quetevotetxapote\n#cañas\n#libertaddeexpresion\n#censura\n#necios\n#gobiernosinutilesytraidores\n#demagogia \n#tapas \n#electricas\n#engañar \n#ocultar \n#casomediador\n#legislación\n#politicos \n#españa🇪🇸\n#cultura\n#tribunal\n#tribunalsupremo\n#gastronomiaespañola\n#letras\n#españa\n#fakenews\n#cgpj\n#losmeconios\n#gobiernosinutilesytraidores'}, {'id': '17931128000699722', 'permalink': 'https://www.instagram.com/p/CtnnEWBI_87/', 'comments_count': 100, 'like_count': 10978, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/354361307_223614907189016_4207466813130316554_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=W888IwB59ukAX-HRDgY&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfDEuzerQhmol8G6mlU5K4g9Dqk2RRvFVHHlrd0GbxZU-w&oe=649C71E4', 'timestamp': '2023-06-18T04:49:58+0000', 'caption': 'Lmaoo who can relate ? #EpsteinDidntKillHimself #Hellywood #ItsABigClub Credit: 👉🏽 jeffrey.a.hann \n\n😂\n\nCheck out my Friends...\n\n📢\n\nflatworldlogic\njohn_logan_coots \nstillshininbitches\nvegantierraplana\n \nFor our Plane(t) 🌎 \n\n✊🏽\n\n#hollyweird #weird #conspiracy #mindcontrol #xfiles #kanyewest #scary #mkultra #sheeple #wisdom #knowledge #fakenews #conscious  #nwo #newworldorder #illuminati #tv #chemtrails #flatearth #occult #instagram #strange #celebrity #celebrities #thinkbeforesharing #clone'}, {'id': '18277441684131904', 'permalink': 'https://www.instagram.com/p/CtpdhfDuF9X/', 'comments_count': 30, 'like_count': 1089, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/354419880_957026622173032_9118826805754914544_n.jpg?_nc_cat=104&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=HmmbKFmS_FYAX97H8Bh&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfA1lLF ...
# Adding posts from batch
# 997
# 47902
# {'url': 'https://graph.facebook.com/v17.0/17843857336037659/top_media?access_token=EAAETCS5I9KkBANFIqMkG6jBtxpabq5LbnpZBhe3riXQWaHwGCxNN0GIjzYbmGAmPydKlvndGW2aCwoF7siJfbryQP3mXFvCZB48jWCVvUlsLL5nDI0zvuKo3ZCwX5oCg0kMegKB6OoR29x8FQkYJUGk3EBO68cJUj8Mx3uiIvbZCH78988b4&fields=id%2Cpermalink%2Ccomments_count%2Clike_count%2Cmedia_type%2Cmedia_url%2Ctimestamp%2Ccaption&user_id=17841460143570104&limit=50&after=NTE0OThlODU2MjY3NDJkMzkyYmY0MzM2NjNjYTNhM2EZD', 'endpoint_params': '', 'endpoint_params_pretty': '""', 'json_data': {'data': [{'id': '17980966259246672', 'permalink': 'https://www.instagram.com/p/Ct1Gcbttd7T/', 'comments_count': 9, 'like_count': 80, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/355399860_188375624202589_6267760928383452469_n.heic?stp=dst-jpg&_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=XUKRrMiVV78AX-ZTZfA&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfBZpeWwVMgzDz07d3JMKtHdageKfnsMcYZb6Dc5L3ONeA&oe=649B4140', 'timestamp': '2023-06-23T10:34:16+0000', 'caption': 'Extremadura es como un clon de Andalucía. Los que ahora salen y salieron, diciendo que los cuarenta años de Franco y bla bla bla bla. Creo que si no me fallan los cálculos, el PSOE estuvo en Andalucia cuarenta años..o treinta y ocho ¿porqué? pueden mirar la famosa y única Ley de las muchas discriminatorias, llamada PER...un invento de Felipe González, donde en toda España, los jornaleros tenían un privilegio. Luego vino vino Zapatero en el dos mil ocho y se cargó el art 14 "todos los españoles somos iguales sin distinción..."con su Ley de VG.\n\nAhora la veleta rubia, se dedica en plan progres, a hacer y poner a parir a otro partido, llamándolos de todo, simplemente por la razón de sus ideales, bastante igualitarios sin chiringuitos ni distinciones. Pero la avaricia de creerse progre azul, prefiere pactar con los desechos de las elecciones. Aún sabiendo que habrá nuevas...\n\nPero mientras, se dedica como buena yegua a trotar y cabalgar, en el populismo rancio de ideales de colores e ideologías de minorías, cultura woke, etcétera\n\nOtra Blancanieves de Disney versión actual...\n\nbuenos diassss... fachassssss!!!\n\n#prohibido\n#añonuevo\n#bar\n#quetevotetxapote\n#cañas\n#libertaddeexpresion\n#censura\n#necios\n#gobiernosinutilesytraidores\n#demagogia \n#tapas \n#electricas\n#engañar \n#ocultar \n#casomediador\n#legislación\n#politicos \n#españa🇪🇸\n#cultura\n#tribunal\n#tribunalsupremo\n#gastronomiaespañola\n#letras\n#españa\n#fakenews\n#cgpj\n#losmeconios\n#gobiernosinutilesytraidores'}, {'id': '17931128000699722', 'permalink': 'https://www.instagram.com/p/CtnnEWBI_87/', 'comments_count': 100, 'like_count': 10978, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/354361307_223614907189016_4207466813130316554_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=W888IwB59ukAX-HRDgY&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfDEuzerQhmol8G6mlU5K4g9Dqk2RRvFVHHlrd0GbxZU-w&oe=649C71E4', 'timestamp': '2023-06-18T04:49:58+0000', 'caption': 'Lmaoo who can relate ? #EpsteinDidntKillHimself #Hellywood #ItsABigClub Credit: 👉🏽 jeffrey.a.hann \n\n😂\n\nCheck out my Friends...\n\n📢\n\nflatworldlogic\njohn_logan_coots \nstillshininbitches\nvegantierraplana\n \nFor our Plane(t) 🌎 \n\n✊🏽\n\n#hollyweird #weird #conspiracy #mindcontrol #xfiles #kanyewest #scary #mkultra #sheeple #wisdom #knowledge #fakenews #conscious  #nwo #newworldorder #illuminati #tv #chemtrails #flatearth #occult #instagram #strange #celebrity #celebrities #thinkbeforesharing #clone'}, {'id': '18277441684131904', 'permalink': 'https://www.instagram.com/p/CtpdhfDuF9X/', 'comments_count': 30, 'like_count': 1089, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/354419880_957026622173032_9118826805754914544_n.jpg?_nc_cat=104&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=HmmbKFmS_FYAX97H8Bh&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfA1lLF ...
# Adding posts from batch
# 998
# 47950
# {'url': 'https://graph.facebook.com/v17.0/17843857336037659/top_media?access_token=EAAETCS5I9KkBANFIqMkG6jBtxpabq5LbnpZBhe3riXQWaHwGCxNN0GIjzYbmGAmPydKlvndGW2aCwoF7siJfbryQP3mXFvCZB48jWCVvUlsLL5nDI0zvuKo3ZCwX5oCg0kMegKB6OoR29x8FQkYJUGk3EBO68cJUj8Mx3uiIvbZCH78988b4&fields=id%2Cpermalink%2Ccomments_count%2Clike_count%2Cmedia_type%2Cmedia_url%2Ctimestamp%2Ccaption&user_id=17841460143570104&limit=50&after=NTE0OThlODU2MjY3NDJkMzkyYmY0MzM2NjNjYTNhM2EZD', 'endpoint_params': '', 'endpoint_params_pretty': '""', 'json_data': {'data': [{'id': '17980966259246672', 'permalink': 'https://www.instagram.com/p/Ct1Gcbttd7T/', 'comments_count': 9, 'like_count': 80, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/355399860_188375624202589_6267760928383452469_n.heic?stp=dst-jpg&_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=XUKRrMiVV78AX-ZTZfA&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfBZpeWwVMgzDz07d3JMKtHdageKfnsMcYZb6Dc5L3ONeA&oe=649B4140', 'timestamp': '2023-06-23T10:34:16+0000', 'caption': 'Extremadura es como un clon de Andalucía. Los que ahora salen y salieron, diciendo que los cuarenta años de Franco y bla bla bla bla. Creo que si no me fallan los cálculos, el PSOE estuvo en Andalucia cuarenta años..o treinta y ocho ¿porqué? pueden mirar la famosa y única Ley de las muchas discriminatorias, llamada PER...un invento de Felipe González, donde en toda España, los jornaleros tenían un privilegio. Luego vino vino Zapatero en el dos mil ocho y se cargó el art 14 "todos los españoles somos iguales sin distinción..."con su Ley de VG.\n\nAhora la veleta rubia, se dedica en plan progres, a hacer y poner a parir a otro partido, llamándolos de todo, simplemente por la razón de sus ideales, bastante igualitarios sin chiringuitos ni distinciones. Pero la avaricia de creerse progre azul, prefiere pactar con los desechos de las elecciones. Aún sabiendo que habrá nuevas...\n\nPero mientras, se dedica como buena yegua a trotar y cabalgar, en el populismo rancio de ideales de colores e ideologías de minorías, cultura woke, etcétera\n\nOtra Blancanieves de Disney versión actual...\n\nbuenos diassss... fachassssss!!!\n\n#prohibido\n#añonuevo\n#bar\n#quetevotetxapote\n#cañas\n#libertaddeexpresion\n#censura\n#necios\n#gobiernosinutilesytraidores\n#demagogia \n#tapas \n#electricas\n#engañar \n#ocultar \n#casomediador\n#legislación\n#politicos \n#españa🇪🇸\n#cultura\n#tribunal\n#tribunalsupremo\n#gastronomiaespañola\n#letras\n#españa\n#fakenews\n#cgpj\n#losmeconios\n#gobiernosinutilesytraidores'}, {'id': '17931128000699722', 'permalink': 'https://www.instagram.com/p/CtnnEWBI_87/', 'comments_count': 100, 'like_count': 10978, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/354361307_223614907189016_4207466813130316554_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=W888IwB59ukAX-HRDgY&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfDEuzerQhmol8G6mlU5K4g9Dqk2RRvFVHHlrd0GbxZU-w&oe=649C71E4', 'timestamp': '2023-06-18T04:49:58+0000', 'caption': 'Lmaoo who can relate ? #EpsteinDidntKillHimself #Hellywood #ItsABigClub Credit: 👉🏽 jeffrey.a.hann \n\n😂\n\nCheck out my Friends...\n\n📢\n\nflatworldlogic\njohn_logan_coots \nstillshininbitches\nvegantierraplana\n \nFor our Plane(t) 🌎 \n\n✊🏽\n\n#hollyweird #weird #conspiracy #mindcontrol #xfiles #kanyewest #scary #mkultra #sheeple #wisdom #knowledge #fakenews #conscious  #nwo #newworldorder #illuminati #tv #chemtrails #flatearth #occult #instagram #strange #celebrity #celebrities #thinkbeforesharing #clone'}, {'id': '18277441684131904', 'permalink': 'https://www.instagram.com/p/CtpdhfDuF9X/', 'comments_count': 30, 'like_count': 1089, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/354419880_957026622173032_9118826805754914544_n.jpg?_nc_cat=104&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=HmmbKFmS_FYAX97H8Bh&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfA1lLF ...
# Adding posts from batch
# 999
# 47998
# {'url': 'https://graph.facebook.com/v17.0/17843857336037659/top_media?access_token=EAAETCS5I9KkBANFIqMkG6jBtxpabq5LbnpZBhe3riXQWaHwGCxNN0GIjzYbmGAmPydKlvndGW2aCwoF7siJfbryQP3mXFvCZB48jWCVvUlsLL5nDI0zvuKo3ZCwX5oCg0kMegKB6OoR29x8FQkYJUGk3EBO68cJUj8Mx3uiIvbZCH78988b4&fields=id%2Cpermalink%2Ccomments_count%2Clike_count%2Cmedia_type%2Cmedia_url%2Ctimestamp%2Ccaption&user_id=17841460143570104&limit=50&after=NTE0OThlODU2MjY3NDJkMzkyYmY0MzM2NjNjYTNhM2EZD', 'endpoint_params': '', 'endpoint_params_pretty': '""', 'json_data': {'data': [{'id': '17980966259246672', 'permalink': 'https://www.instagram.com/p/Ct1Gcbttd7T/', 'comments_count': 9, 'like_count': 80, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/355399860_188375624202589_6267760928383452469_n.heic?stp=dst-jpg&_nc_cat=107&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=XUKRrMiVV78AX-ZTZfA&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfBZpeWwVMgzDz07d3JMKtHdageKfnsMcYZb6Dc5L3ONeA&oe=649B4140', 'timestamp': '2023-06-23T10:34:16+0000', 'caption': 'Extremadura es como un clon de Andalucía. Los que ahora salen y salieron, diciendo que los cuarenta años de Franco y bla bla bla bla. Creo que si no me fallan los cálculos, el PSOE estuvo en Andalucia cuarenta años..o treinta y ocho ¿porqué? pueden mirar la famosa y única Ley de las muchas discriminatorias, llamada PER...un invento de Felipe González, donde en toda España, los jornaleros tenían un privilegio. Luego vino vino Zapatero en el dos mil ocho y se cargó el art 14 "todos los españoles somos iguales sin distinción..."con su Ley de VG.\n\nAhora la veleta rubia, se dedica en plan progres, a hacer y poner a parir a otro partido, llamándolos de todo, simplemente por la razón de sus ideales, bastante igualitarios sin chiringuitos ni distinciones. Pero la avaricia de creerse progre azul, prefiere pactar con los desechos de las elecciones. Aún sabiendo que habrá nuevas...\n\nPero mientras, se dedica como buena yegua a trotar y cabalgar, en el populismo rancio de ideales de colores e ideologías de minorías, cultura woke, etcétera\n\nOtra Blancanieves de Disney versión actual...\n\nbuenos diassss... fachassssss!!!\n\n#prohibido\n#añonuevo\n#bar\n#quetevotetxapote\n#cañas\n#libertaddeexpresion\n#censura\n#necios\n#gobiernosinutilesytraidores\n#demagogia \n#tapas \n#electricas\n#engañar \n#ocultar \n#casomediador\n#legislación\n#politicos \n#españa🇪🇸\n#cultura\n#tribunal\n#tribunalsupremo\n#gastronomiaespañola\n#letras\n#españa\n#fakenews\n#cgpj\n#losmeconios\n#gobiernosinutilesytraidores'}, {'id': '17931128000699722', 'permalink': 'https://www.instagram.com/p/CtnnEWBI_87/', 'comments_count': 100, 'like_count': 10979, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/354361307_223614907189016_4207466813130316554_n.jpg?_nc_cat=109&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=W888IwB59ukAX-HRDgY&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfDEuzerQhmol8G6mlU5K4g9Dqk2RRvFVHHlrd0GbxZU-w&oe=649C71E4', 'timestamp': '2023-06-18T04:49:58+0000', 'caption': 'Lmaoo who can relate ? #EpsteinDidntKillHimself #Hellywood #ItsABigClub Credit: 👉🏽 jeffrey.a.hann \n\n😂\n\nCheck out my Friends...\n\n📢\n\nflatworldlogic\njohn_logan_coots \nstillshininbitches\nvegantierraplana\n \nFor our Plane(t) 🌎 \n\n✊🏽\n\n#hollyweird #weird #conspiracy #mindcontrol #xfiles #kanyewest #scary #mkultra #sheeple #wisdom #knowledge #fakenews #conscious  #nwo #newworldorder #illuminati #tv #chemtrails #flatearth #occult #instagram #strange #celebrity #celebrities #thinkbeforesharing #clone'}, {'id': '18277441684131904', 'permalink': 'https://www.instagram.com/p/CtpdhfDuF9X/', 'comments_count': 30, 'like_count': 1089, 'media_type': 'IMAGE', 'media_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/354419880_957026622173032_9118826805754914544_n.jpg?_nc_cat=104&ccb=1-7&_nc_sid=8ae9d6&_nc_ohc=HmmbKFmS_FYAX97H8Bh&_nc_ht=scontent-iad3-1.cdninstagram.com&edm=APCawUEEAAAA&oh=00_AfA1lLF ...
# Adding posts from batch

# %%
post_df2=pd.DataFrame(posts3)

# %%
post_df2.to_csv('fakenews_posts_top2.csv')

# %%
len(post_df2)
# Out:
# 48046

# %%
post_df2
# Out:
#                       id                                 permalink  \
# 0      17995805485951380  https://www.instagram.com/p/CtzKB9Fqgzs/
# 1      18252464551088991  https://www.instagram.com/p/CtwWtb4qH8_/
# 2      17931593675701711  https://www.instagram.com/p/CtzFYGFB0J7/
# 3      17975632772357476  https://www.instagram.com/p/Ct0z_5oSoEV/
# 4      17990473949033476  https://www.instagram.com/p/CtxHc42hyxK/
# ...                  ...                                       ...
# 18739  18077861137366922  https://www.instagram.com/p/CtL8d_NPt8y/
# 18740  17940648821559487  https://www.instagram.com/p/Ctvu1Qupj_-/
# 18741  17985677819143795  https://www.instagram.com/p/Ctz8mVXLr9v/
# 18742  18099416200325640  https://www.instagram.com/p/CtgOIgnMH_D/
# 18743  17914013798684285  https://www.instagram.com/p/CtziH17r_9X/
#
#        comments_count      media_type  \
# 0                  27           IMAGE
# 1                  31  CAROUSEL_ALBUM
# 2                 305  CAROUSEL_ALBUM
# 3                  62  CAROUSEL_ALBUM
# 4                  45  CAROUSEL_ALBUM
# ...               ...             ...
# 18739               3           IMAGE
# 18740               0  CAROUSEL_ALBUM
# 18741               0           IMAGE
# 18742               1           IMAGE
# 18743               0           IMAGE
#
#                                                media_url  \
# 0      https://scontent-iad3-2.cdninstagram.com/v/t51...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 18739  https://scontent-iad3-2.cdninstagram.com/v/t51...
# 18740                                                NaN
# 18741  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 18742  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 18743  https://scontent-iad3-2.cdninstagram.com/v/t51...
#
#                       timestamp  \
# 0      2023-06-22T16:27:07+0000
# 1      2023-06-21T14:20:12+0000
# 2      2023-06-22T15:46:27+0000
# 3      2023-06-23T07:53:05+0000
# 4      2023-06-21T21:26:06+0000
# ...                         ...
# 18739  2023-06-07T10:58:14+0000
# 18740  2023-06-21T08:31:44+0000
# 18741  2023-06-22T23:49:00+0000
# 18742  2023-06-15T07:57:24+0000
# 18743  2023-06-22T19:57:38+0000
#
#                                                  caption  like_count
# 0      The submarine that went missing during a missi...         NaN
# 1      The submarine carrying five individuals, inclu...         NaN
# 2      Swipe ⬅️ The oxygen supply of 96 hours on the ...      6162.0
# 3      Everything you should know about Aryans»\n.\n....      5756.0
# 4      It doesn’t sound like a ruff job. A US billion...      1564.0
# ...                                                  ...         ...
# 18739     #NewsUpdate #knowledgeofself #knowledgeispower      1092.0
# 18740  😍 #காரைக்காலில் இன்று 9வது சர்வதேச யோகா தின நி...      2822.0
# 18741  Perú tiene nueva Miss Grand y es la hermosa lu...        10.0
# 18742  વાવાઝોડા અસરગ્રસ્ત વિસ્તારોમાં જો મોબાઈલ નેટવર...       815.0
# 18743  "سندھ حکومت عوام کے لئے کروڑوں کی سبسڈی دے رہی...         7.0
#
# [18744 rows x 8 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4c8af7b1-f3b8-45ab-bbdc-6a32713107d1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
